# %% [markdown]
# # Tuple

# %%
Tuple is a Collection Datatype

Tuple Support Multiple Datatype

Tuple Store Duplicates

Tuple is a Immutable Datatype

Tuple Support Indexing Or SLicing

# %% [markdown]
# # Creating Tuple

# %%
mytuple=("Banana","Apple","Orange","Papaya")

# %%
print(mytuple)
print(type(mytuple))
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya')
# <class 'tuple'>

# %%
# Check Lenght
print(len(mytuple))
# Out:
# 4

# %%
thistuple=("Apple")

# %%
print(type(thistuple))
# Out:
# <class 'str'>

# %%
thistuple=("Apple",)  # Create Tuple With One Item

# %%
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
# Create Blank Tuple
blank_tuple=()
print(type(blank_tuple))
# Out:
# <class 'tuple'>

# %%
print(blank_tuple)
# Out:
# ()

# %%
data=(50,"Vishnu",4.5,True,8+9j,[3,56])  # Tuple  Store Mutiple Data Type

# %%
print(type(data))
# Out:
# <class 'tuple'>

# %%
store_tuple=tuple((80,50,60,40))

# %%
print(type(store_tuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# # Access Tuple Element

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya')

# %%
org=mytuple[2]

# %%
print(org)
# Out:
# Orange

# %%
apple=mytuple[-3]

# %%
apple
# Out:
# 'Apple'

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya')

# %%
data=mytuple[0:3]  # Slicing

# %%
data
# Out:
# ('Banana', 'Apple', 'Orange')

# %%
thistuple=(50,60,80,90,10,"Vishnu Ghosh","Rohit","Karan")
if "Vishnu Ghosh" in thistuple:
    print("Yes Exists ")
else:
    print("Not Exists")
# Out:
# Yes Exists

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya')

# %%
mytuple[1]='PineApple'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mytuple[1]='PineApple'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Update Tuple Element
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya')

# %%
y=list(mytuple)  # Type Casting

# %%
print(y)
# Out:
# ['Banana', 'Apple', 'Orange', 'Papaya']

# %%
type(y)
# Out:
# list

# %%
mytuple[1]="Kiwi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 mytuple[1]="Kiwi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
y
# Out:
# ['Banana', 'Apple', 'Orange', 'Papaya']

# %%
y[1]="Kiwi"

# %%
y
# Out:
# ['Banana', 'Kiwi', 'Orange', 'Papaya']

# %%
mytuple=tuple(y)

# %%
mytuple
# Out:
# ('Banana', 'Kiwi', 'Orange', 'Papaya')

# %%
mytuple.append("Grapes")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mytuple.append("Grapes")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
y=list(mytuple)
y.append("Grapes")
mytuple=tuple(y)

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya', 'Grapes')

# %%
a=[80,90]
b=[100,200]
# clear_output[80,90,100,200]
print(a+b)
# Out:
# [80, 90, 100, 200]

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya', 'Grapes')

# %%
c=("PineApple",)

# %%
type(c)
# Out:
# tuple

# %%
mytuple=mytuple+c

# %%
print(mytuple+c)
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya', 'Grapes', 'PineApple', 'PineApple')

# %%
y=list(mytuple)

# %%
y
# Out:
# ['Banana', 'Apple', 'Orange', 'Papaya', 'Grapes', 'PineApple']

# %%
y.remove("PineApple")

# %%
type(mytuple)
# Out:
# tuple

# %%
type(y)
# Out:
# list

# %%
y
# Out:
# ['Banana', 'Kiwi', 'Orange', 'Papaya', 'Grapes']

# %%
y.remove("Kiwi")

# %%
y
# Out:
# ['Banana', 'Orange', 'Papaya', 'Grapes']

# %%
mytuple=tuple(y)

# %%
mytuple
# Out:
# ('Banana', 'Apple', 'Orange', 'Papaya', 'Grapes')

# %%
del mytuple

# %%
mytuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %%
data=(80,8,0,80,90,90,14,14,63,52)
data.count(80)
# Out:
# 2

# %%
data.index(52)
# Out:
# 9

# %%
data[9]
# Out:
# 52

# %%
data
# Out:
# (80, 8, 0, 80, 90, 90, 14, 14, 63, 52)

# %%
thistuple
# Out:
# (50, 60, 80, 90, 10, 'Vishnu', 'Rohit', 'Karan')

# %%
fruits=("Banana","Apple","Grapes","Papaya","Pineapple")  # Packing

# %%
# Upacking
(yellow,red,*green,orange)=fruits

# %%
print(red)
# Out:
# Apple

# %%
print(orange)
# Out:
# Pineapple

# %%
print(orange)
# Out:
# ['Papaya']

# %%
print(green)
# Out:
# ['Grapes', 'Papaya']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

# %%
(green, *tropic, red) = fruits
# print(green)
print(tropic)
# print(red)
# Out:
# ['mango', 'papaya', 'pineapple']

# %%
print(red)
# Out:
# cherry

# %%
fruits
# Out:
# ('apple', 'mango', 'papaya', 'pineapple', 'cherry')

# %%
# apple
# mango
# papaya
# pineapple
# cherry

print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
print(fruits[4])
# Out:
# apple
# mango
# papaya
# pineapple
# cherry

# %%
for i in fruits:
    print(i)
# Out:
# apple
# mango
# papaya
# pineapple
# cherry

# %%
for i in fruits:
    if len(i)<=6:
        print(i)
    else:
        break
# Out:
# apple
# mango
# papaya

# %%
data=fruits*2
print(data)
# Out:
# ('apple', 'mango', 'papaya', 'pineapple', 'cherry', 'apple', 'mango', 'papaya', 'pineapple', 'cherry')

# %%
a=(10,20)
b=(40,50)
print((a+b)*2)
# Out:
# (10, 20, 40, 50, 10, 20, 40, 50)

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Tuple Comprehension

# %%
tuple1=(83,91,80,50,60,40)
a=list(i for i in tuple1)

# %%
a
# Out:
# [83, 91, 80, 50, 60, 40]

# %%
for i in tuple1:
    # print(i)
    if i%2==0:
        print(i)
# Out:
# 80
# 50
# 60
# 40
