# %%
# Set is a Collection Datatype

# Set is Mutable

# Set is Unordered

# Set Doesn't Store Duplicated Element

# Indexing/Slicing Not Possible

# Set Literal is {} value sepreated by comma(,)

# %%
setA={}

# %%
print(type(setA))
# Out:
# <class 'dict'>

# %%
seta=set()

# %%
type(seta)
# Out:
# set

# %%
data={10,10,20,20,30,30}
print(data)
# Out:
# {10, 20, 30}

# %%
records={10,"Python",5.2,True,(50,10)}

# %%
set1={'apple',"banana","grapes"}

# %%
print(set1)
# Out:
# {'grapes', 'apple', 'banana'}

# %%
set1.add("Mango")

# %%
set1
# Out:
# {'Mango', 'apple', 'banana', 'grapes'}

# %%
fruits={'Mango', 'apple', 'banana', 'grapes'}
fruits.update(['coconut','pineapple'])

# %%
fruits
# Out:
# {'Mango', 'apple', 'banana', 'coconut', 'grapes', 'pineapple'}

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# {'Mango', 'apple', 'coconut', 'grapes', 'pineapple'}

# %%
fruits.remove('banana')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 fruits.remove('banana')
#
# KeyError: 'banana'

# %%
fruits.discard('coconut')

# %%
fruits
# Out:
# {'Mango', 'apple', 'grapes', 'pineapple'}

# %%
marks={10,45,'',60,54,90}
marks.pop()
# Out:
# ''

# %%
marks
# Out:
# {10, 45, 54, 60, 90}

# %%
marks.pop()
# Out:
# 90

# %%
marks.pop()
# Out:
# 54

# %%
marks
# Out:
# {10, 45, 60}

# %%
marks.pop()
# Out:
# 10

# %%
marks.clear()

# %%
marks
# Out:
# set()

# %%
a={10,20,30}
b={20,40,60}
c=a.union(b)
print(c)
# Out:
# {20, 40, 10, 60, 30}

# %%
a={10,20,30}
b={20,40,60}
c=a|b
print(c)
# Out:
# {20, 40, 10, 60, 30}

# %%
a={10,20,30}
b={20,40,60}
c=a&b
print(c)
# Out:
# {20}

# %%
a={10,20,30}
b={20,40,60}
c=a.intersection(b)
print(c)
# Out:
# {20}

# %%
A={1,2,3,4,5,6}
B={5,6,7,8,9,10}
diff=B-A
print(diff)
# Out:
# {8, 9, 10, 7}

# %%
A={1,2,3,4,5,6}
B={5,6,7,8,9,10}
diff=B.difference(A)
print(diff)
# Out:
# {8, 9, 10, 7}

# %%
A={1,2,3,4,5,6}
B={5,6,7,8,9,10}
# output(1,2,3,4,7,8,9,10)
result=A.symmetric_difference(B)
print(result)
# Out:
# {1, 2, 3, 4, 7, 8, 9, 10}

# %%
A={1,2}
B={1,2,3,4}
print(A.issubset(B))
# Out:
# True

# %%
A={1,2}
B={1,2,3,4}
print(B.issubset(A))
# Out:
# False

# %%
A={1,2,3,4}
B={1,2}
print(A.issuperset(B))
# Out:
# True

# %%
print(B.issuperset(A))
# Out:
# False

# %%
A={1,2,3,4}
B={1,2}
print(A.isdisjoint(B))
# Out:
# False

# %%
A={1,2,3,4}
B={5,6}
print(A.isdisjoint(B))
# Out:
# True

# %%
number=set()
for i in range(1,6):
    number.add(i)
print(number)
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers={i for i in range(1,6)}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}
