# %% [markdown]
# # List
#
# 1. List Literal is []
#
# 2. List Ordered.
#
# 3. List is a Collection Datatype
#
# 4. List Store Duplicates
#
# 5. List Support Indexing/Slicing
#
# 6. List Mutable/Changeble
#
# 7. List Support To store Multiple Datatypes.

# %% [markdown]
# # Creating List

# %%
list1=[]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
print(list1)
# Out:
# []

# %%
list2=[34,23,546]

# %%
print(type(list2))
# Out:
# <class 'list'>

# %%
print(list2)
# Out:
# [34, 23, 546]

# %%
list1=[]

# %%
print(list1)
# Out:
# []

# %% [markdown]
# # Insert Element in List

# %%
list1.append(30)

# %%
list1
# Out:
# [30]

# %%
list1.append(80)

# %%
list1
# Out:
# [30, 80]

# %%
list1.append([45,43,21])

# %%
list1
# Out:
# [30, 80, [45, 43, 21]]

# %%
index range
positve--- 0  to n
negative  -- -1 to -n

# %%
list3=list1[2]
list4=list1[-1]

# %%
list3
# Out:
# [45, 43, 21]

# %%
list4
# Out:
# [45, 43, 21]

# %%
list1
# Out:
# [30, 80, [45, 43, 21]]

# %%
list1.append(100)

# %%
list1
# Out:
# [30, 80, [45, 43, 21], 100]

# %%
list1.insert(2,500)

# %%
list1.insert(3,500)

# %%
list1
# Out:
# [30, 80, 500, 500, [45, 43, 21], 100]

# %%
[30, 80, 500, 500, [45, 43, 21,1000], 100]

# %%
list1[4].append(1000)

# %%
list1
# Out:
# [30, 80, 500, 500, [45, 43, 21, 1000], 100]

# %%
a=10
b=a
a=20
print(a,b)
# Out:
# 20 10

# %%
a=print("Python")
print(a)
# Out:
# Python
# None

# %%
print()

# %%
print(print(print(print("Hello World"))))
# Out:
# Hello World
# None
# None
# None

# %% [markdown]
# # Delete Method in List

# %%
list1
# Out:
# [30, 80, 500, 500, [45, 43, 21, 1000], 100]

# %%
list1.pop()
# Out:
# 100

# %%
list1
# Out:
# [30, 80, 500, 500, [45, 43, 21, 1000]]

# %%
list1.remove(500)

# %%
list1
# Out:
# [30, 80, 500, [45, 43, 21, 1000]]

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
list1=[30, 80, 500, 500, [45, 43, 21], 100]

# %%
list1
# Out:
# [30, 80, 500, 500, [45, 43, 21], 100]

# %%
del list1[0]

# %%
list1
# Out:
# [80, 500, 500, [45, 43, 21], 100]

# %%
del list1[1:3]

# %%
list1
# Out:
# [80, [45, 43, 21], 100]

# %%
poped_value=list1.pop(1)

# %%
poped_value
# Out:
# [45, 43, 21]

# %%
a=[30, 80, 500, 500, [45, 43, 21], 100,[87,5,4,69,45],[100,400,[50,60,70],800],1000]

# %%
a
# Out:
# [30,
#  80,
#  500,
#  500,
#  [45, 43, 21],
#  100,
#  [87, 5, 4, 69, 45],
#  [100, 400, [50, 60, 70], 800],
#  1000]

# %%
print([a[7][1],a[8],a[4][1],a[0],a[6][1]])
# Out:
# [400, 1000, 43, 30, 5]

# %%
output=
[400,1000,43,30,5]

# %%
a=[80,50,60]
b=[90,85,47]
c=a+b
print(c)
# Out:
# [80, 50, 60, 90, 85, 47]

# %%
c.index(90)
# Out:
# 3

# %%
c.extend(a)

# %%
c
# Out:
# [80, 50, 60, 90, 85, 47, 80, 50, 60]

# %%
class1=["Ramesh","Mohan","Gopal"]
class2=["Ravi","Nandan"]
class2.extend(class1)

# %%
class2
# Out:
# ['Ravi', 'Nandan', 'Ramesh', 'Mohan', 'Gopal']

# %%
class1.extend(class2)

# %%
class1
# Out:
# ['Ramesh', 'Mohan', 'Gopal', 'Ravi', 'Nandan', 'Ramesh', 'Mohan', 'Gopal']

# %%
b=a.copy()

# %%
b
# Out:
# [80, 50, 60]

# %%
class1
# Out:
# ['Ramesh', 'Mohan', 'Gopal', 'Ravi', 'Nandan', 'Ramesh', 'Mohan', 'Gopal']

# %%
class1.count("Ramesh")
# Out:
# 2

# %%
class1.sort()

# %%
class1
# Out:
# ['Gopal', 'Gopal', 'Mohan', 'Mohan', 'Nandan', 'Ramesh', 'Ramesh', 'Ravi']

# %%
class1.reverse()

# %%
class1
# Out:
# ['Ravi', 'Ramesh', 'Ramesh', 'Nandan', 'Mohan', 'Mohan', 'Gopal', 'Gopal']

# %%
data=[80,70,88,73,14,96,54,63,77,67,60,98,45,68,32,39,30]
data.sort()

# %%
data
# Out:
# [14, 30, 32, 39, 45, 54, 60, 63, 67, 68, 70, 73, 77, 80, 88, 96, 98]

# %%
data.reverse()

# %%
data
# Out:
# [98, 96, 88, 80, 77, 73, 70, 68, 67, 63, 60, 54, 45, 39, 32, 30, 14]

# %%
data.sort()

# %%
data
# Out:
# [14, 30, 32, 39, 45, 54, 60, 63, 67, 68, 70, 73, 77, 80, 88, 96, 98]

# %%
data.sort(reverse=False)

# %%
data
# Out:
# [14, 30, 32, 39, 45, 54, 60, 63, 67, 68, 70, 73, 77, 80, 88, 96, 98]

# %% [markdown]
# # Nested List

# %%
data=[[[80,50,60],54,[99,87],55,69,78],100]

# %%
[ index-0
   [  index 1
    [  index   0
        80,50,60
    ],54 index 1

    [99 ,87]  index 2

       
   ]
]

# %%
data
# Out:
# [[[80, 50, 60], 54, [99, 87], 55, 69, 78], 100]

# %%
b=data[0][2]

# %%
b
# Out:
# [99, 87]
