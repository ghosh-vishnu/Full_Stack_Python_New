# %%
# Integer Data Type
1. int
2. float
3. complex

# %%
a=54
print(type(a))
# Out:
# <class 'int'>

# %%
a='54'
print(type(a))
# Out:
# <class 'str'>

# %%
num1=input("Enter Your First Number")
num2=input("Enter Your Secound Number")
print(type(num1))
print(type(num2))
add=num1+num2
print("The Addtion of Entered Number is ",add)
# Out:
# <class 'str'>
# <class 'str'>
# The Addtion of Entered Number is  1020

# %%
num1='20'
num2='50'
add=num1+num2
print(add)
# Out:
# 2050

# %%
num1=int(input("Enter Your First Number"))
num2=int(input("Enter Your Secound Number"))
print(type(num1))
print(type(num2))
add=num1+num2
print("The Addtion of Entered Number is ",add)
# Out:
# <class 'int'>
# <class 'int'>
# The Addtion of Entered Number is  63

# %% [markdown]
# # Type Casting

# %%
a="Python"
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 a="Python"
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'Python'

# %%
a='30'
b=int(a)
print(b)
print(f"The Data Type of {b} is {type(b)}")
print(a)
print(f"The Data Type of {a} is {type(a)}")
# Out:
# 30
# The Data Type of 30 is <class 'int'>
# 30
# The Data Type of 30 is <class 'str'>

# %%
a=500
print(type(a))
# Out:
# <class 'int'>

# %%
b=str(a)

# %%
print(b)
print(type(b))
# Out:
# 500
# <class 'str'>

# %%
a=50
b=78
print(a+b)
# Out:
# 128

# %%
print(a*b)
# Out:
# 3900

# %%
print(a/b)
# Out:
# 0.6410256410256411

# %%
print(a//b)
# Out:
# 0

# %%
print(a%b)
# Out:
# 50

# %% [markdown]
# # Float

# %%
a=50.5

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
a=4.5
b=6.5
c=a+b
print(c)
# Out:
# 11.0

# %%
c
# Out:
# 11.0

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
# Convert float to int
value=int(c)

# %%
value
# Out:
# 11

# %%
num=78.9
new_num=int(num)
print(new_num)
# Out:
# 78

# %%
# float to str
a=85.5
b=str(a)
print(type(b))
print(b)
# Out:
# <class 'str'>
# 85.5

# %%
# int to float
y=87
float_value=float(y)
print(float_value)
# Out:
# 87.0

# %%
# str to float
d='10.5'
b=float(d)
print(b)
# Out:
# 10.5

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
b
# Out:
# 10.5

# %%
a=99.5
str_value=str(a)
print(str_value)
# Out:
# 99.5

# %%
type(str_value)
# Out:
# str

# %%
name="Vishnu"
# output:-
# This is Vishnu and Vishnu is 24 years old.
print("This is",name,"and",name,"is Years old")
print(f"This is {name} and {name} is years old ")
# Out:
# This is Vishnu and Vishnu is Years old
# This is Vishnu and Vishnu is years old
