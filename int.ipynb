# %%
# Integer Data Type
1. int
2. float
3. complex

# %%
a=54
print(type(a))

# %%
a='54'
print(type(a))

# %%
num1=input("Enter Your First Number")
num2=input("Enter Your Secound Number")
print(type(num1))
print(type(num2))
add=num1+num2
print("The Addtion of Entered Number is ",add)

# %%
num1='20'
num2='50'
add=num1+num2
print(add)

# %%
num1=int(input("Enter Your First Number"))
num2=int(input("Enter Your Secound Number"))
print(type(num1))
print(type(num2))
add=num1+num2
print("The Addtion of Entered Number is ",add)

# %% [markdown]
# # Type Casting

# %%
a="Python"
b=int(a)
print(b)

# %%
a='30'
b=int(a)
print(b)
print(f"The Data Type of {b} is {type(b)}")
print(a)
print(f"The Data Type of {a} is {type(a)}")

# %%
a=500
print(type(a))

# %%
b=str(a)

# %%
print(b)
print(type(b))

# %%
a=50
b=78
print(a+b)

# %%
print(a*b)

# %%
print(a/b)

# %%
print(a//b)

# %%
print(a%b)

# %% [markdown]
# # Float

# %%
a=50.5

# %%
print(type(a))

# %%
a=4.5
b=6.5
c=a+b
print(c)

# %%
c

# %%
print(type(c))

# %%
# Convert float to int
value=int(c)

# %%
value

# %%
num=78.9
new_num=int(num)
print(new_num)

# %%
# float to str
a=85.5
b=str(a)
print(type(b))
print(b)

# %%
# int to float
y=87
float_value=float(y)
print(float_value)

# %%
# str to float
d='10.5'
b=float(d)
print(b)

# %%
print(type(b))

# %%
b

# %%
a=99.5
str_value=str(a)
print(str_value)

# %%
type(str_value)

# %%
name="Vishnu"
# output:-
# This is Vishnu and Vishnu is 24 years old.
print("This is",name,"and",name,"is Years old")
print(f"This is {name} and {name} is years old ")
