# %% [markdown]
# # Variables in Python:-

# %%
Varaible is Just like a Container which store Values
example-
A=20
a----variable
20---Values

# %%
Rules To Define Variable:-
1. Never Start Varaiable name with Number.
2. Never use Special Character like (!@#$%^&*()))  for naming Variable Expect of _(underscore)

# %%
@name="Vishnu"
# Out:
#   Cell In[1], line 1
#     @name="Vishnu"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
123name="Vishnu"
# Out:
#   Cell In[2], line 1
#     123name="Vishnu"
#       ^
# SyntaxError: invalid decimal literal

# %%
name@="Vishnu"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 name@="Vishnu"
#
# NameError: name 'name' is not defined

# %%
_12=10

# %%
print(_12)
# Out:
# 10

# %%
_12@=68
print(_12@)
# Out:
#   Cell In[9], line 2
#     print(_12@)
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Python is Case-Sencative language

# %%
A=10
a=20
print(A)
# Out:
# 10

# %%
print(a)
# Out:
# 20

# %% [markdown]
# # String in Python

# %%
a="1234560"
print(type(a))
# Out:
# <class 'str'>

# %%
b='1230'
print(type(b))
# Out:
# <class 'str'>

# %%
c="""56y86"""
print(type(c))
# Out:
# <class 'str'>

# %%
d='''567587000'''
print(type(d))
# Out:
# <class 'str'>

# %%
e=1245
print(type(e))
# Out:
# <class 'int'>

# %%
print(e)
# Out:
# 1245

# %%
f="vishnu"
print(type(f))
# Out:
# <class 'str'>

# %%
# String Concatination

# %%
first_name="Vishnu"
last_name="Ghosh"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# Vishnu Ghosh

# %%
print(len(full_name))
# Out:
# 12

# %%
print(full_name.upper())
# Out:
# VISHNU GHOSH

# %%
print(full_name.lower())
# Out:
# vishnu ghosh

# %%
print(full_name.split())
# Out:
# ['Vishnu', 'Ghosh']

# %%
print(full_name.casefold())
# Out:
# vishnu ghosh

# %%
print(full_name.count('s'))
# Out:
# 2

# %%
full_name
# Out:
# 'Vishnu Ghosh'

# %%
print(full_name.find("V"))
# Out:
# 0

# %%
full_name
# Out:
# 'Vishnu Ghosh'

# %%
print(full_name.find("h"))
# Out:
# 3

# %% [markdown]
# # Seprator

# %%
first_name
# Out:
# 'Vishnu'

# %%
last_name
# Out:
# 'Ghosh'

# %%
print(first_name,last_name,sep="#12")
# Out:
# Vishnu#12Ghosh

# %%
print(first_name,last_name,sep="@")
# Out:
# Vishnu@Ghosh

# %%
print(first_name,last_name,sep=" Kumar ")
# Out:
# Vishnu Kumar Ghosh

# %% [markdown]
# # End Operator

# %%
print(first_name,end="@123")
# Out:
# Vishnu@123

# %%
print(first_name,end=" Kumar")
# Out:
# Vishnu Kumar

# %% [markdown]
# # Input Function

# %%
first_name=input("Enter Your First Name ")
last_name=input('Enter Your Last Name ')
full_name=first_name+' '+last_name
print(full_name)
# Out:
# Vishnu Kumar

# %%
print(type(full_name))
# Out:
# <class 'str'>

# %% [markdown]
# # Indexing & Slicing

# %%
text="Python Devloper"
P--0    -15
Y--1    -14
T--2    -13
H--3    -12
O--4    -11
N--5    -10
 --6    -9
D --7   -8
e--8    -7
v--9    -6
l--10   -5
o--11   -4
p--12   -3
e--13   -2
r--14   -1

# %%
text="Python Devloper"
print(text.find('D'))
# Out:
# 7

# %%
print(text[-14])
# Out:
# y

# %% [markdown]
# # Slicing

# %%
name="Rohit Kumar"
first_name=name[0:5]
last_name=name[6::]
print(last_name)
print(first_name)
# Out:
# Kumar
# Rohit

# %%
print(text[0:6])
# Out:
# Python

# %%
print(text[:6])
# Out:
# Python

# %%
print(text[7:15])
# Out:
# Devloper

# %%
print(text[7:])
# Out:
# Devloper

# %%
# Reverse String
print(text[::-1])
# Out:
# repolveD nohtyP

# %%
print(text[-5:0])

# %%
num1=int(input("Enter Your First Number"))
num2=int(input("Enter Your Secound Number"))
print(type(num1))
print(type(num2))
add=num1+num2
print("The Addtion of Entered Number is ",add)
# Out:
# <class 'int'>
# <class 'int'>
# The Addtion of Entered Number is  110

# %%
num1=input("Enter Your First Number")
num2=input("Enter Your Secound Number")
print(type(num1))
print(type(num2))
add=int(num1)+int(num2)
print("The Addtion of Entered Number is ",add)
# Out:
# <class 'str'>
# <class 'str'>
# The Addtion of Entered Number is  118

# %%
data="Apple"
value=int(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 data="Apple"
# ----> 2 value=int(data)
#
# ValueError: invalid literal for int() with base 10: 'Apple'

# %%
data="780"
value=int

# %%
print(type(data))
print(type(value))
print(value)
# Out:
# <class 'str'>
# <class 'int'>
# 780

# %%
number=1000
pin=str(number)
print("The Datatype of PIN varable is ",type(pin))
print("The Datatype of Number varable is ",type(number))
# Out:
# The Datatype of PIN varable is  <class 'str'>
# The Datatype of Number varable is  <class 'int'>

# %%
int to str
str to int
float to int
int to float
float to str
str to float

# %%
# Float
value=8.9
print(type(value))
# Out:
# <class 'float'>

# %%
# float to int
int_value=int(value)
print(int_value)
# Out:
# 8

# %%
# int to float
num2=85
num3=float(num2)
print(num3)
# Out:
# 85.0

# %%
# float to str
float_value=8.5
str_float=str(float_value)
print(str_float)
# Out:
# 8.5

# %%
print(type(str_float))
# Out:
# <class 'str'>

# %%
# str to float
float_str='19.5'
float_value=float(float_str)
print(type(float_value))
print(float_value)
# Out:
# <class 'float'>
# 19.5

# %%
# Complex Data Type
a=4+3j
b=5+9j
print(a+b)
# Out:
# (9+12j)

# %%
print(type(a))
# Out:
# <class 'complex'>

# %%
# Complex Data Type
a=4+3j
b=5+9j
print(a+b)
# Out:
# (9+12j)

# %%
# Complex Data Type
a=4.5+3j
b=5.9+9j
print(a+b)
# Out:
# (10.4+12j)

# %%
# complex=(int+float)+(alfa_numeric ka combinataion char with only j)
data_value=74+5j
print(type(data_value))
# Out:
# <class 'complex'>

# %%
# can we convert complex to str(YES/NO) 
# Answer  YES
str_complex=str(data_value)

# %%
print(str_complex)
print(type(str_complex))
# Out:
# (74+5j)
# <class 'str'>

# %%
# Can we convert str to complex(YES/NO)
# Answer  Yes with Complex Condition ()
str_value="Python"
complex_conversation=complex(str_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 # Can we convert str to complex(YES/NO)
#       2 # Answer  NO
#       3 str_value="Python"
# ----> 4 complex_conversation=complex(str_value)
#
# ValueError: complex() arg is a malformed string

# %%
str_Data='6+9j'
complex_data=complex(str_Data)
print(type(complex_data))
# Out:
# <class 'complex'>

# %%
complex1=input("Enter a first Complex Number")
complex2=input("Enter a Secound Complex Number")
complex_sum=complex(complex1)+complex(complex2)
print(complex_sum)
# Out:
# (17+17j)

# %%
# Numerical Data Type Does Not Support Indexing/Slicing

# %% [markdown]
# # Boolean  Datatype
# > 1. True
# > 2. False

# %%
age=17
is_adult=age>=18
print(is_adult)
# Out:
# False

# %%
is_login=True
is_admin=False
print(is_admin)
# Out:
# False

# %%
is_login=False
if is_login:
    print("Welcome to Dashboard")
else:
    print("Please Login First")
# Out:
# Please Login First
