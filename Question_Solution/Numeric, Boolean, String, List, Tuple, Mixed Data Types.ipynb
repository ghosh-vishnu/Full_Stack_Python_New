# %%
# . Find the second largest digit in a number.
a=[90,60,15,80,63,87]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
a.sort()

# %%
a[-2]
# Out:
# 87

# %%
b=[84,15,18,19,90,85,64]
b.sort()
b[-2]
# Out:
# 85
